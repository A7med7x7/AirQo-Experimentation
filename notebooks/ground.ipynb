# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
def post_process(test_data,y,feature_to_mean='date_month') -> int:
    """runs the post processing

    Keyword arguments:
    test_data -- the testing data
    y -- the target
    feature_to_mean -- feature to apply the post processing by
    Return: predictions after processing
    """
    test_data['target'] = y
    test_data['target_month'] = test_data[feature_to_mean].map(test_data[[feature_to_mean,'target']].groupby(feature_to_mean)['target'].mean())
    test_data.drop(columns='target',inplace=True)
    return test_data['target_month']

# %%
ground=pd.read_csv('/Users/apple2/Desktop/airqo/ground-monitor.csv')

# %%
ground.head()
# Out:
#                  timestamp                   site_id  pm2_5   city  latitude  \
# 0  2019-11-27 09:00:00 UTC  636f69b295dc52002992ebb2    NaN  Accra  5.580642
# 1  2019-11-27 10:00:00 UTC  636f69b295dc52002992ebb2    NaN  Accra  5.580642
# 2  2019-11-27 11:00:00 UTC  636f69b295dc52002992ebb2    NaN  Accra  5.580642
# 3  2019-11-27 12:00:00 UTC  636f69b295dc52002992ebb2    NaN  Accra  5.580642
# 4  2019-11-27 13:00:00 UTC  636f69b295dc52002992ebb2    NaN  Accra  5.580642
#
#    longitude
# 0  -0.170724
# 1  -0.170724
# 2  -0.170724
# 3  -0.170724
# 4  -0.170724

# %%
test = pd.read_csv("Test.csv")
ID=test['id']
ground_train=ground.dropna()
ground_test = ground[ground.isna().any(axis=1)]
test=test[['date','site_id','city','site_latitude','site_longitude']]

# %%
test.head()
# Out:
#          date                   site_id   city  site_latitude  site_longitude
# 0  2023-09-06  64f9d17ab9e98d001ac9e882  Accra        5.61252        -0.22955
# 1  2023-09-07  64f9d17ab9e98d001ac9e882  Accra        5.61252        -0.22955
# 2  2023-09-08  64f9d17ab9e98d001ac9e882  Accra        5.61252        -0.22955
# 3  2023-09-09  64f9d17ab9e98d001ac9e882  Accra        5.61252        -0.22955
# 4  2023-09-20  64f9d17ab9e98d001ac9e882  Accra        5.61252        -0.22955

# %%
ground_train.head()
# Out:
#                    timestamp                   site_id  pm2_5   city  \
# 162  2019-12-05 00:00:00 UTC  636f69b295dc52002992ebb2    3.6  Accra
# 163  2019-12-05 01:00:00 UTC  636f69b295dc52002992ebb2    3.8  Accra
# 166  2019-12-05 04:00:00 UTC  636f69b295dc52002992ebb2    1.9  Accra
# 167  2019-12-05 05:00:00 UTC  636f69b295dc52002992ebb2   54.5  Accra
# 168  2019-12-05 06:00:00 UTC  636f69b295dc52002992ebb2  185.8  Accra
#
#      latitude  longitude
# 162  5.580642  -0.170724
# 163  5.580642  -0.170724
# 166  5.580642  -0.170724
# 167  5.580642  -0.170724
# 168  5.580642  -0.170724

# %%
# ground_train['longitude'].nunique()

# %%
ground_train['date']=ground_train['timestamp']
# Out:
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/982669255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ground_train['date']=ground_train['timestamp']

# %%
for df in (ground_train,test):
    df['date'] = pd.to_datetime(df['date'])
    df['date_month'] = df['date'].dt.day_of_year
    df['DayOfWeek'] =  df['date'].dt.dayofweek
    df['Hour'] =  df['date'].dt.hour
    df['Day'] =  df['date'].dt.day
    df['Year'] =  df['date'].dt.year
    df.drop(columns=['date','city'],inplace=True)
# Out:
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_month'] = df['date'].dt.day_of_year
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] =  df['date'].dt.dayofweek
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] =  df['date'].dt.hour
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] =  df['date'].dt.day
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] =  df['date'].dt.year
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/3924530062.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['date','city'],inplace=True)

# %%
ground_train.drop('timestamp',axis=1,inplace=True)
# Out:
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/665171997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ground_train.drop('timestamp',axis=1,inplace=True)

# %%
groups = ground_train['site_id']

# %%
ground_train.head()
# Out:
#                       site_id  pm2_5  latitude  longitude  date_month  \
# 162  636f69b295dc52002992ebb2    3.6  5.580642  -0.170724         339
# 163  636f69b295dc52002992ebb2    3.8  5.580642  -0.170724         339
# 166  636f69b295dc52002992ebb2    1.9  5.580642  -0.170724         339
# 167  636f69b295dc52002992ebb2   54.5  5.580642  -0.170724         339
# 168  636f69b295dc52002992ebb2  185.8  5.580642  -0.170724         339
#
#      DayOfWeek  Hour  Day  Year
# 162          3     0    5  2019
# 163          3     1    5  2019
# 166          3     4    5  2019
# 167          3     5    5  2019
# 168          3     6    5  2019

# %%
le = LabelEncoder()
for column in ['site_id']:
    letrans = le.fit_transform(pd.concat([ground_train,test])[column])
    ground_train[column] = letrans[:len(ground_train)]
    test[column] = letrans[len(ground_train):]
# Out:
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/4227427185.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ground_train[column] = letrans[:len(ground_train)]

# %%
ground_train.head()
# Out:
#      site_id  pm2_5  latitude  longitude  date_month  DayOfWeek  Hour  Day  \
# 162       10    3.6  5.580642  -0.170724         339          3     0    5
# 163       10    3.8  5.580642  -0.170724         339          3     1    5
# 166       10    1.9  5.580642  -0.170724         339          3     4    5
# 167       10   54.5  5.580642  -0.170724         339          3     5    5
# 168       10  185.8  5.580642  -0.170724         339          3     6    5
#
#      Year
# 162  2019
# 163  2019
# 166  2019
# 167  2019
# 168  2019

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error         # Regressortion metric
from sklearn.model_selection import GroupKFold,KFold

# %%
model =  LGBMRegressor(n_estimators=200,random_state=42,max_depth=10)
n_splits = 4
cv = GroupKFold(n_splits=n_splits)

# %%
train_set = pd.read_csv('/Users/apple2/Desktop/airqo/ground-monitor.csv')

def validate(trainset,testset,t,origin):
    model.fit(trainset.drop(columns=t),trainset[t])
    pred = model.predict(np.array(testset.drop(columns=t)))
    print('std: ', testset[t].std())
    # pred = post_process(origin,pred,'date_month')

    origin['pm_5'] = pred
    origin['timestamp'] = pd.to_datetime(origin['timestamp'])
    origin['date_day'] = origin['timestamp'].dt.month
    pred = origin['date_day'].map(origin[['date_day','pm_5']].groupby('date_day')['pm_5'].mean())
    stds.append(testset[t].std())
    score = mean_squared_error(pred,testset[t],squared=False)
    print('score:', score)
    return score
stds = []
rmse = []
for v_train,v_test in cv.split(ground_train.drop(columns='pm2_5'),ground_train['pm2_5'],groups=groups):
    train_v, test_v= ground_train.iloc[v_train],ground_train.iloc[v_test]
    origin = train_set.iloc[v_test]
    rmse.append(validate(train_v,test_v,'pm2_5',origin))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001588 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 520
# [LightGBM] [Info] Number of data points in the train set: 242324, number of used features: 8
# [LightGBM] [Info] Start training from score 25.032450
# std:  27.20900670767594
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['timestamp'] = pd.to_datetime(origin['timestamp'])
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['timestamp'].dt.month
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# score: 27.161685342837007
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001390 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 517
# [LightGBM] [Info] Number of data points in the train set: 242475, number of used features: 8
# [LightGBM] [Info] Start training from score 25.595340
# std:  27.514573747257028
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['timestamp'] = pd.to_datetime(origin['timestamp'])
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['timestamp'].dt.month
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# score: 26.835973769310016
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002210 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 524
# [LightGBM] [Info] Number of data points in the train set: 242323, number of used features: 8
# [LightGBM] [Info] Start training from score 26.760225
# std:  20.302562109845532
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['timestamp'] = pd.to_datetime(origin['timestamp'])
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['timestamp'].dt.month
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# score: 20.487623454152786
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 516
# [LightGBM] [Info] Number of data points in the train set: 242400, number of used features: 8
# [LightGBM] [Info] Start training from score 26.745522
# std:  18.483068973039963
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# score: 18.362807103370468
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['timestamp'] = pd.to_datetime(origin['timestamp'])
# /var/folders/hx/d_6hvkqx7kj5qwb2hts0bynh0000gp/T/ipykernel_11105/1380426063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['timestamp'].dt.month
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
np.array(rmse).mean()
# Out:
# 23.212022417417568

# %%
model.fit(ground_train.drop(columns='pm2_5'),ground_train['pm2_5'])
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003249 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 585
# [LightGBM] [Info] Number of data points in the train set: 323174, number of used features: 8
# [LightGBM] [Info] Start training from score 26.033371
# LGBMRegressor(max_depth=10, n_estimators=200, random_state=42)

# %%
y = model.predict(test)

# %%
smaple = pd.read_csv('SampleSubmission.csv')
smaple['pm2_5'] = post_process(test,y)
smaple.to_csv('submission6.csv',index=False)
